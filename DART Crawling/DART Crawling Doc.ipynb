# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
from pandas.io.json import json_normalize
from selenium import webdriver
import time
import re
import matplotlib.pyplot as plt

# %% [markdown]
# # 유가증권 기업코드 가져오기

# %%
file_path = 'C:/Users/elris/Python/Untitled Folder/상장법인목록.xlsx'

df = pd.read_excel(file_path, sheet_name='Sheet1')
df.head(20)
# Out:
#          회사명    종목코드                                     업종  \
# 0    케이씨씨글라스  344820                          유리 및 유리제품 제조업
# 1    NH프라임리츠  338100                           부동산 임대 및 공급업
# 2      센트랄모텍  308170                          자동차 신품 부품 제조업
# 3   현대에너지솔루션  322000                                반도체 제조업
# 4      한화시스템  272210  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 5     자이에스앤디  317400                           부동산 임대 및 공급업
# 6       롯데리츠  330590                           부동산 임대 및 공급업
# 7        지누스   13890                                 가구 제조업
# 8      두산솔루스  336370                               전자부품 제조업
# 9      두산퓨얼셀  336260      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 10    제이콘텐트리   36420              영화, 비디오물, 방송프로그램 제작 및 배급업
# 11    포스코케미칼    3670                       내화, 비내화 요업제품 제조업
# 12    현대오토에버  307950                         소프트웨어 개발 및 공급업
# 13       드림텍  192650                               전자부품 제조업
# 14    더블유게임즈  192080                         소프트웨어 개발 및 공급업
# 15    우리금융지주  316140                                 기타 금융업
# 16      에어부산  298690                              항공 여객 운송업
# 17   아시아나IDT  267850                컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 18      세아제강  306200                              1차 철강 제조업
# 19      하나제약  293480                                의약품 제조업
#
#                                                주요제품        상장일  결산월  \
# 0                                             판유리 등 2020-01-21  12월
# 1                                            부동산 투자 2019-12-05  11월
# 2          이너레이스, 오디 클러치보스, 로터샤프트, 슬리브기어, 컨트롤 암, 엑슬 2019-11-25  12월
# 3                              태양광 셀·모듈, PV시스템, ESS 2019-11-19  12월
# 4   정밀기기(육해공군관련전자제어시스템,열영상감시장비,탐지추적장치,전투지휘체계시스템) 제조 2019-11-13  12월
# 5   부동산 관리, 정보통신 공사, 아파트 AS 및 옵션 제품 공급, 건축물 시공 및 분양 2019-11-06  12월
# 6                                             부동산투자 2019-10-30  06월
# 7                                       매트리스 및 가구제품 2019-10-30  12월
# 8                                        동박, 유압기기 등 2019-10-18  12월
# 9                                              연료전지 2019-10-18  12월
# 10                           영화 및 방송프로그램 제작, 유통, 광고 2019-10-18  12월
# 11                              내화물, 생석회, 음극재 및 양극재 2019-05-29  12월
# 12                 전산실운영, 시스템구축, 전산장비 납품, SOC/건축 사업 2019-03-28  12월
# 13                    모바일 PBA, 지문인식 모듈, 전장 LED 모듈 등 2019-03-14  12월
# 14                                           온라인 게임 2019-03-12  12월
# 15                                             금융지주 2019-02-13  12월
# 16                                    항공 여객 및 화물 운송 2018-12-27  12월
# 17                                   IT 서비스, IT 솔루션 2018-11-23  12월
# 18                                               강관 2018-10-05  12월
# 19                                            완제의약품 2018-10-02  12월
#
#            대표자명                             홈페이지     지역
# 0           김내환        http://www.kccglass.co.kr  서울특별시
# 1           박영희           http://www.nhreits.com  서울특별시
# 2           이종철    http://www.centralmotek.co.kr  울산광역시
# 3           강철호     http://www.hyundai-es.co.kr/    경기도
# 4           김연철         http://hanwhasystems.com   경상북도
# 5           김환열            http://www.xisnd.com/  서울특별시
# 6   롯데에이엠씨 주식회사      http://www.lottereit.co.kr/  서울특별시
# 7           이윤재           http://www.zinus.co.kr    경기도
# 8           이윤석       http://www.doosansolus.com   전라북도
# 9           유수경    http://www.doosanfuelcell.com   전라북도
# 10          제찬웅      http://www.jcontentree.com/  서울특별시
# 11          민경준    http://www.poscochemical.com/   경상북도
# 12          오일석  http://www.hyundai-autoever.com  서울특별시
# 13          김형민      http://www.idreamtech.co.kr    경기도
# 14          김가람                              NaN  서울특별시
# 15          손태승          http://www.woorifg.com/  서울특별시
# 16          한태근          http://www.airbusan.com  부산광역시
# 17          박세창         http://www.asianaidt.com  서울특별시
# 18     이휘령, 김석일       http://www.seahsteel.co.kr  서울특별시
# 19          이윤하          http://www.hanaph.co.kr    경기도

# %% [markdown]
# # 기업년도별 사업보고서 가져오기

# %%
import re
from bs4 import BeautifulSoup
import requests
import json
import time
import pandas as pd

data = pd.DataFrame()
for num,i in enumerate(test_data['종목코드']) :    
    time.sleep(1)
    api_code = 'Key'
    start_date = '19900101'
    crp_code = '0'*(6-len(str(i))) + str(i)
    url = 'http://dart.fss.or.kr/api/search.json'
    params = {
        'auth' : api_code,
        'crp_cd' : crp_code,
        'start_dt' : start_date,
        'bsn_tp' : 'A001'
    }
    req = requests.get(url, params=params)
    html = req.text
    code = json.loads(html)
    soup = BeautifulSoup(html,'html.parser')
    for t in code['list']:
        temp = pd.DataFrame(([[t['crp_cls'],t['crp_nm'],t['crp_cd'],
                               t['rpt_nm'],t['rcp_no'],t['flr_nm'],t['rcp_dt'],t['rmk']]])
                            ,columns=["crp_cls","crp_nm","crp_cd","rpt_nm","rcp_no","flr_nm","rcp_dt","rmk"])
        data = pd.concat([data,temp])
    data.reset_index(drop=True,inplace=True)

for i in range(0, len(data)) : 
    if len(data['rpt_nm'][i]) > 20 : 
        data.drop([i], inplace=True)
        
data.reset_index(drop=True,inplace=True)  
display(data.head(27))
# Out:
#    crp_cls   crp_nm  crp_cd           rpt_nm          rcp_no   flr_nm  \
# 0        Y      지누스  013890  사업보고서 (2018.12)  20190401004071      지누스
# 1        Y      지누스  013890  사업보고서 (2017.12)  20180402005273      지누스
# 2        Y      지누스  013890  사업보고서 (2016.12)  20170331004281      지누스
# 3        Y   제이콘텐트리  036420  사업보고서 (2018.12)  20190401004270   제이콘텐트리
# 4        Y   제이콘텐트리  036420  사업보고서 (2017.12)  20180402004265   제이콘텐트리
# 5        Y   제이콘텐트리  036420  사업보고서 (2016.12)  20170331004977   제이콘텐트리
# 6        Y   제이콘텐트리  036420  사업보고서 (2015.12)  20160330003573   제이콘텐트리
# 7        Y   제이콘텐트리  036420  사업보고서 (2014.12)  20150331004337   제이콘텐트리
# 8        Y   제이콘텐트리  036420  사업보고서 (2013.12)  20140331002484   제이콘텐트리
# 9        Y   제이콘텐트리  036420  사업보고서 (2012.12)  20130401002152   제이콘텐트리
# 10       Y   포스코케미칼  003670  사업보고서 (2018.12)  20190329004409   포스코케미칼
# 11       Y   포스코케미칼  003670  사업보고서 (2017.12)  20180330003359   포스코케미칼
# 12       Y   포스코케미칼  003670  사업보고서 (2016.12)  20170331003706   포스코케미칼
# 13       Y   포스코케미칼  003670  사업보고서 (2015.12)  20160330004396   포스코케미칼
# 14       Y   포스코케미칼  003670  사업보고서 (2014.12)  20150331002855   포스코케미칼
# 15       Y   포스코케미칼  003670  사업보고서 (2013.12)  20140328001243   포스코케미칼
# 16       Y   포스코케미칼  003670  사업보고서 (2012.12)  20130328000761   포스코케미칼
# 17       Y   현대오토에버  307950  사업보고서 (2018.12)  20190401004896   현대오토에버
# 18       Y      드림텍  192650  사업보고서 (2018.12)  20190401003862      드림텍
# 19       Y   더블유게임즈  192080  사업보고서 (2018.12)  20190329002898   더블유게임즈
# 20       Y   더블유게임즈  192080  사업보고서 (2017.12)  20180330000907   더블유게임즈
# 21       Y   더블유게임즈  192080  사업보고서 (2016.12)  20170330001138   더블유게임즈
# 22       Y   더블유게임즈  192080  사업보고서 (2015.12)  20160329000657   더블유게임즈
# 23       Y     에어부산  298690  사업보고서 (2018.12)  20190401005207     에어부산
# 24       Y  아시아나IDT  267850  사업보고서 (2018.12)  20190401005182  아시아나IDT
# 25       Y     세아제강  306200  사업보고서 (2018.12)  20190401002387     세아제강
# 26       Y     하나제약  293480  사업보고서 (2018.12)  20190401001889     하나제약
#
#       rcp_dt rmk
# 0   20190401  정연
# 1   20180402  정연
# 2   20170331  정연
# 3   20190401  정연
# 4   20180402   연
# 5   20170331  정연
# 6   20160330  정연
# 7   20150331   연
# 8   20140331   연
# 9   20130401   연
# 10  20190401   연
# 11  20180330  정연
# 12  20170331   연
# 13  20160330   연
# 14  20150331   연
# 15  20140328  정연
# 16  20130328   연
# 17  20190401  정연
# 18  20190401   연
# 19  20190329   연
# 20  20180330  정연
# 21  20170330   연
# 22  20160329   정
# 23  20190401   정
# 24  20190401  정연
# 25  20190401
# 26  20190401

# %% [markdown]
# # 해당 사업보고서에서 이사의 경영진단 part  url 파라메터 가져오기

# %%
rcpNo_list=[]
dcmNo_list=[]
eleId_list=[]
offset_list=[]
length_list=[]
dtd_list=[]

for i in range(0,len(data)) : 
    try : 
        time.sleep(1)
        start_date = '19900101'
        crp_code = data['crp_cd'][i]
        rcpNo = data['rcp_no'][i]
        url = 'http://dart.fss.or.kr/dsaf001/main.do'
        params = {
            'rcpNo' : rcpNo,
            'crp_cd' : 'crp_code'
            }
        req =requests.get(url, params=params)
        html = req.text
        soup = BeautifulSoup(html,'html.parser')
        soup.find('head')
        body = str(soup.find('head')).split('이사의 경영진단 및 분석의견",')[1].split('cnt++')[0].split('viewDoc(')[1].split(')')[0].split(', ')
        body = [body[i][1:-1] for i in range(len(body))]     
        rcpNo_list.append(body[0]) 
        dcmNo_list.append(body[1])
        eleId_list.append(body[2])
        offset_list.append(body[3])
        length_list.append(body[4])
        dtd_list.append(body[5])
        
    except KeyError:
        data.drop([i], inplace=True)
        continue
        
    except IndexError:
        data.drop([i], inplace=True)
        continue
    
data = data.reset_index(drop=True, inplace=False)
data['dcmNo'] = dcmNo_list
data['eleld'] = eleId_list
data['offset'] = offset_list
data['length'] = length_list
data['dtd'] = dtd_list
display(data)
# Out:
#    crp_cls   crp_nm  crp_cd           rpt_nm          rcp_no   flr_nm  \
# 0        Y      지누스  013890  사업보고서 (2018.12)  20190401004071      지누스
# 1        Y      지누스  013890  사업보고서 (2017.12)  20180402005273      지누스
# 2        Y      지누스  013890  사업보고서 (2016.12)  20170331004281      지누스
# 3        Y   제이콘텐트리  036420  사업보고서 (2018.12)  20190401004270   제이콘텐트리
# 4        Y   제이콘텐트리  036420  사업보고서 (2017.12)  20180402004265   제이콘텐트리
# 5        Y   제이콘텐트리  036420  사업보고서 (2016.12)  20170331004977   제이콘텐트리
# 6        Y   제이콘텐트리  036420  사업보고서 (2015.12)  20160330003573   제이콘텐트리
# 7        Y   제이콘텐트리  036420  사업보고서 (2014.12)  20150331004337   제이콘텐트리
# 8        Y   제이콘텐트리  036420  사업보고서 (2013.12)  20140331002484   제이콘텐트리
# 9        Y   제이콘텐트리  036420  사업보고서 (2012.12)  20130401002152   제이콘텐트리
# 10       Y   포스코케미칼  003670  사업보고서 (2018.12)  20190329004409   포스코케미칼
# 11       Y   포스코케미칼  003670  사업보고서 (2017.12)  20180330003359   포스코케미칼
# 12       Y   포스코케미칼  003670  사업보고서 (2016.12)  20170331003706   포스코케미칼
# 13       Y   포스코케미칼  003670  사업보고서 (2015.12)  20160330004396   포스코케미칼
# 14       Y   포스코케미칼  003670  사업보고서 (2014.12)  20150331002855   포스코케미칼
# 15       Y   포스코케미칼  003670  사업보고서 (2013.12)  20140328001243   포스코케미칼
# 16       Y   포스코케미칼  003670  사업보고서 (2012.12)  20130328000761   포스코케미칼
# 17       Y   현대오토에버  307950  사업보고서 (2018.12)  20190401004896   현대오토에버
# 18       Y      드림텍  192650  사업보고서 (2018.12)  20190401003862      드림텍
# 19       Y   더블유게임즈  192080  사업보고서 (2018.12)  20190329002898   더블유게임즈
# 20       Y   더블유게임즈  192080  사업보고서 (2017.12)  20180330000907   더블유게임즈
# 21       Y   더블유게임즈  192080  사업보고서 (2016.12)  20170330001138   더블유게임즈
# 22       Y   더블유게임즈  192080  사업보고서 (2015.12)  20160329000657   더블유게임즈
# 23       Y     에어부산  298690  사업보고서 (2018.12)  20190401005207     에어부산
# 24       Y  아시아나IDT  267850  사업보고서 (2018.12)  20190401005182  아시아나IDT
# 25       Y     세아제강  306200  사업보고서 (2018.12)  20190401002387     세아제강
# 26       Y     하나제약  293480  사업보고서 (2018.12)  20190401001889     하나제약
#
#       rcp_dt rmk    dcmNo eleld   offset length        dtd
# 0   20190401  정연  6612621    18  1072993  11386  dart3.xsd
# 1   20180402  정연  6061284    19  1000928  11327  dart3.xsd
# 2   20170331  정연  5539159    19   645468  12210  dart3.xsd
# 3   20190401  정연  6613787    18  1316291  19303  dart3.xsd
# 4   20180402   연  6057075    19  1266419  19604  dart3.xsd
# 5   20170331  정연  5542781    19  1535823  19481  dart3.xsd
# 6   20160330  정연  5026283    19  1626053  18947  dart3.xsd
# 7   20150331   연  4563482    19  1563554  20006  dart3.xsd
# 8   20140331   연  4114982    13   281654  19012  dart3.xsd
# 9   20130401   연  3710232    13   348565  19240  dart3.xsd
# 10  20190401   연  6595330    18  1298810  68203  dart3.xsd
# 11  20180330  정연  6040070    19  1202220  63988  dart3.xsd
# 12  20170331   연  5536282    19  1193520  32690  dart3.xsd
# 13  20160330   연  5030550    19  1153211  37457  dart3.xsd
# 14  20150331   연  4556330    19  1026021  35411  dart3.xsd
# 15  20140328  정연  4101074    13   229521  28233  dart3.xsd
# 16  20130328   연  3688869    13   247942  21710  dart3.xsd
# 17  20190401  정연  6617365    18   900320  39544  dart3.xsd
# 18  20190401   연  6611538    18  1287542  16055  dart3.xsd
# 19  20190329   연  6589638    18  1010753  19800  dart3.xsd
# 20  20180330  정연  6030553    19   988294  18980  dart3.xsd
# 21  20170330   연  5518897    19   929986  19698  dart3.xsd
# 22  20160329   정  5007731    19   731021  18127  dart3.xsd
# 23  20190401   정  6618971    18   597732  31580  dart3.xsd
# 24  20190401  정연  6618853    18   906370  18147  dart3.xsd
# 25  20190401      6605146    18   479075  18478  dart3.xsd
# 26  20190401      6602789    18  1076807  34743  dart3.xsd

# %% [markdown]
# # 이사의 경영진단 part 텍스트화 후 데이터 프레임에 저장

# %%
text_list=[] 
num = len(data)
for i in range(0,num) : 
    time.sleep(1)
    target_url = 'http://dart.fss.or.kr/report/viewer.do?'
    params = {
        'rcpNo': data['rcp_no'][i],
        'dcmNo': data['dcmNo'][i],
        'eleId' : data['eleld'][i],
        'offset' : data['offset'][i],
        'length' : data['length'][i],
        'dtd' : data['dtd'][i]
    }
    resp = requests.get(target_url, params=params)
    dom = BeautifulSoup(resp.text,'html.parser')

    all_content = list(dom)
    content_list = []
    for i in all_content : 
        str_content = str(i).split('\n')
        content = str_content
        content_list += content

    table = dom.find_all('table')
    table_str = str(table)
    table_split = table_str.split('\n')
    table_list = table_split

    del_list = []
    for x in content_list : 
        if x in table_list : 
            del_list.append(x)
    for d in del_list :
        content_list.remove(d)
    text = str(content_list)


    def cleanr(content):
        text = re.sub('[-=+,#/\:^$.@*\"※~&%ㆍ』\\‘|\(\)\[\]\<\>`\'…》]', '', content)
        return text

    text = cleanr(text)
    text_list.append(text)
data['text'] = text_list

# %%
data.to_excel('./기업텍스트.xlsx', header=True, index=True)
